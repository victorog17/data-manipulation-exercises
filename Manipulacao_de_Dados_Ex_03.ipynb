# %% [markdown]
# <a href="https://colab.research.google.com/github/victorog17/data-manipulation-exercises/blob/master/Manipulacao_de_Dados_Ex_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://i.imgur.com/JsMvGnP.png)

# %% [markdown]
# ## Exercícios de manipulação de dados - Parte 3

# %% [markdown]
# Neste Jupyter notebook você irá resolver uma exercícios utilizando a biblioteca Pandas.\
# Todos os datasets utilizados nos exercícios estão salvos na pasta *datasets*.\
# Todo o seu código deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.

# %% [markdown]
# #### Tarefa 1. Importe o dataset e salve os dados em um dataframe
#
# Os dados estão salvos no arquivo ***datasets/users_dataset.txt***.\
# Salve os dados em uma variável de nome *users*.

# %%
import pandas as pd
users = pd.read_csv('https://raw.githubusercontent.com/victorog17/data-manipulation-exercises/master/datasets/users_dataset.csv', sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# #### Tarefa 2. Descubra qual a idade média por ocupação.
#
# *Dica: use a função groupby do Pandas na coluna occupation*

# %%
users.groupby(['occupation'])['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# #### Tarefa 3. Para cada ocupação descubra a idade mínima e máxima.

# %%
maximo = users.groupby(['occupation'])['age'].agg(age = max)
minimo = users.groupby(['occupation'])['age'].agg(age = min)

idades = maximo
idades.rename(columns={'age' : 'Idade máxima'}, inplace=True)
idades['Idade mínima'] = minimo
idades
# Out:
#                Idade máxima  Idade mínima
# occupation
# administrator            70            21
# artist                   48            19
# doctor                   64            28
# educator                 63            23
# engineer                 70            22
# entertainment            50            15
# executive                69            22
# healthcare               62            22
# homemaker                50            20
# lawyer                   53            21
# librarian                69            23
# marketing                55            24
# none                     55            11
# other                    64            13
# programmer               63            20
# retired                  73            51
# salesman                 66            18
# scientist                55            23
# student                  42             7
# technician               55            21
# writer                   60            18

# %% [markdown]
# #### Tarefa 4. Para cada combinação de ocupação e sexo, calcule a idade média.
#
# Exemplo:
#
# ```
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# ```

# %%
users.groupby(['occupation', 'gender'])['age'].agg(age = 'mean')
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# #### Tarefa 5. Para cada ocupação calcule a porcentagem de homens e mulheres.
#
# Exemplo:
#
# ```
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# ```

# %%
genero = users.groupby(['occupation', 'gender'])['gender'].agg(gender = 'count')
genero_t = users.groupby(['occupation'])['occupation'].agg(occupation = 'count')
genero['porcentagem'] = ((genero.gender / genero_t.occupation) * 100).round(2)
genero
# Out:
#                       gender  porcentagem
# occupation    gender
# administrator F           36        45.57
#               M           43        54.43
# artist        F           13        46.43
#               M           15        53.57
# doctor        M            7       100.00
# educator      F           26        27.37
#               M           69        72.63
# engineer      F            2         2.99
#               M           65        97.01
# entertainment F            2        11.11
#               M           16        88.89
# executive     F            3         9.38
#               M           29        90.62
# healthcare    F           11        68.75
#               M            5        31.25
# homemaker     F            6        85.71
#               M            1        14.29
# lawyer        F            2        16.67
#               M           10        83.33
# librarian     F           29        56.86
#               M           22        43.14
# ...

# %% [markdown]
# **Parabéns! Você chegou ao fim!**
